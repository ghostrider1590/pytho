# %%
from nsepy import get_history
import math
import pandas as pd

# %%
from datetime import date
data = get_history(symbol="SBIN", start=date(2020,6,1), end=date(2020,7,17))

# %%
sbin = get_history(symbol='SBIN',
                   start=date(2020,5,1),
                   end=date(2020,7,17))

# %%
sbin['Averagedel']=sbin['Deliverable Volume'].mean()

# %%
sbin.round(2)
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2020-05-04   SBIN     EQ      190.50  182.45  183.50  178.00  179.30  178.85
# 2020-05-05   SBIN     EQ      178.85  181.00  181.25  168.80  171.40  170.40
# 2020-05-06   SBIN     EQ      170.40  171.15  173.30  166.55  171.95  171.10
# 2020-05-07   SBIN     EQ      171.10  170.85  172.55  168.80  170.95  170.75
# 2020-05-08   SBIN     EQ      170.75  172.45  173.80  166.10  166.90  166.65
# 2020-05-11   SBIN     EQ      166.65  167.95  168.90  165.00  165.25  165.45
# 2020-05-12   SBIN     EQ      165.45  164.20  168.50  160.85  167.10  166.90
# 2020-05-13   SBIN     EQ      166.90  178.55  178.55  170.50  174.50  174.10
# 2020-05-14   SBIN     EQ      174.10  170.95  171.75  167.50  168.30  167.95
# 2020-05-15   SBIN     EQ      167.95  167.95  168.25  164.70  166.45  166.40
# 2020-05-18   SBIN     EQ      166.40  166.40  166.40  155.00  155.45  155.30
# ...

# %%
pd.reset_option('^display.', silent=True)

# %%
sbin['%ofAverage']=(sbin['Deliverable Volume']/sbin['Averagedel'])*100

# %%
sbin.round(2)
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2020-05-04   SBIN     EQ      190.50  182.45  183.50  178.00  179.30  178.85
# 2020-05-05   SBIN     EQ      178.85  181.00  181.25  168.80  171.40  170.40
# 2020-05-06   SBIN     EQ      170.40  171.15  173.30  166.55  171.95  171.10
# 2020-05-07   SBIN     EQ      171.10  170.85  172.55  168.80  170.95  170.75
# 2020-05-08   SBIN     EQ      170.75  172.45  173.80  166.10  166.90  166.65
# 2020-05-11   SBIN     EQ      166.65  167.95  168.90  165.00  165.25  165.45
# 2020-05-12   SBIN     EQ      165.45  164.20  168.50  160.85  167.10  166.90
# 2020-05-13   SBIN     EQ      166.90  178.55  178.55  170.50  174.50  174.10
# 2020-05-14   SBIN     EQ      174.10  170.95  171.75  167.50  168.30  167.95
# 2020-05-15   SBIN     EQ      167.95  167.95  168.25  164.70  166.45  166.40
# 2020-05-18   SBIN     EQ      166.40  166.40  166.40  155.00  155.45  155.30
# ...

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2020-05-04   SBIN     EQ      190.50  182.45  183.50  178.00  179.30  178.85
# 2020-05-05   SBIN     EQ      178.85  181.00  181.25  168.80  171.40  170.40
# 2020-05-06   SBIN     EQ      170.40  171.15  173.30  166.55  171.95  171.10
# 2020-05-07   SBIN     EQ      171.10  170.85  172.55  168.80  170.95  170.75
# 2020-05-08   SBIN     EQ      170.75  172.45  173.80  166.10  166.90  166.65
# 2020-05-11   SBIN     EQ      166.65  167.95  168.90  165.00  165.25  165.45
# 2020-05-12   SBIN     EQ      165.45  164.20  168.50  160.85  167.10  166.90
# 2020-05-13   SBIN     EQ      166.90  178.55  178.55  170.50  174.50  174.10
# 2020-05-14   SBIN     EQ      174.10  170.95  171.75  167.50  168.30  167.95
# 2020-05-15   SBIN     EQ      167.95  167.95  168.25  164.70  166.45  166.40
# 2020-05-18   SBIN     EQ      166.40  166.40  166.40  155.00  155.45  155.30
# ...

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2020-05-04   SBIN     EQ      190.50  182.45  183.50  178.00  179.30  178.85
# 2020-05-05   SBIN     EQ      178.85  181.00  181.25  168.80  171.40  170.40
# 2020-05-06   SBIN     EQ      170.40  171.15  173.30  166.55  171.95  171.10
# 2020-05-07   SBIN     EQ      171.10  170.85  172.55  168.80  170.95  170.75
# 2020-05-08   SBIN     EQ      170.75  172.45  173.80  166.10  166.90  166.65
# 2020-05-11   SBIN     EQ      166.65  167.95  168.90  165.00  165.25  165.45
# 2020-05-12   SBIN     EQ      165.45  164.20  168.50  160.85  167.10  166.90
# 2020-05-13   SBIN     EQ      166.90  178.55  178.55  170.50  174.50  174.10
# 2020-05-14   SBIN     EQ      174.10  170.95  171.75  167.50  168.30  167.95
# 2020-05-15   SBIN     EQ      167.95  167.95  168.25  164.70  166.45  166.40
# 2020-05-18   SBIN     EQ      166.40  166.40  166.40  155.00  155.45  155.30
# ...
